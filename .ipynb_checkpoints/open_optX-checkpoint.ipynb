# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import linmix
from linmix.linmix import LinMix
import math

# %%
filepath = r"C:\Users\Iris Reitsma\Documents\Master\jaar 3\scriptie\optX\NSXBs-jhk.dat"

# read flash.dat to a list of lists
datContent = [i.strip().split() for i in open(filepath).readlines()]
data = pd.DataFrame(data=datContent[1:], columns=datContent[0])

# Drop nan rows
data = data.mask(data.eq('None')).dropna()

# Convert numbers to ints
data['log(Lx)'] = pd.to_numeric(data['log(Lx)'])
data['log(L_nu_OIR)'] = pd.to_numeric(data['log(L_nu_OIR)'])
display(data)
# Out:
#    #Source,    log(Lx)  log(L_nu_OIR) Filter
# 0     J1900  36.265431      18.718271      J
# 1     aqlx1  36.078077      19.383006      J
# 2     4U061  35.995698      18.192096      J
# 3     aqlx1  36.657518      19.583016      J
# 4     aqlx1  36.203739      19.663020      J
# 5     aqlx1  36.368468      19.823028      J
# 6     aqlx1  36.632191      19.983036      J
# 7     aqlx1  36.683142      19.903032      J
# 8     aqlx1  36.255825      19.623018      J
# 10    scox1  38.455331      20.372441      H
# 11    CygX2  38.291103      21.130717      H
# 12    J2123  31.649526      16.960187      H
# 13    J0029  35.393473      18.459402      H
# 14    J0029  35.318973      18.494601      H
# 15    J0029  35.095641      18.431401      H
# 16    J0029  35.302803      18.441802      H
# 17    4U061  35.995698      18.174304      H
# 19   GX17+2  37.996129      20.232557      K
# 20    scox1  38.455331      20.194622      K
# 21    J1808  35.707855      19.191364      K
# 22    J1808  33.838257      17.827297      K
# 23    J1808  34.152651      17.763294      K
# 24    CygX2  38.291103      20.978155      K
# 25    J1701  38.184882      20.118015      K
# 26    CirX1  38.521729      21.951553      K
# 27    CirX1  38.343645      21.999553      K
# 28    CirX1  38.643960      22.263553      K
# 29    CirX1  38.649986      22.299553      K
# 30    CirX1  38.791556      22.311553      K
# 31    CirX1  38.833004      22.115553      K
# 32   4U1608  35.856901      18.827986      K
# 33    4U061  35.995698      18.076768      K

# %%
filepath_bh = r"C:\Users\Iris Reitsma\Documents\Master\jaar 3\scriptie\optX\BHXBs-hard-jhk.dat"

# read flash.dat to a list of lists
datContent_bh = [i.strip().split() for i in open(filepath_bh).readlines()]
data_bh = pd.DataFrame(data=datContent_bh[1:], columns=datContent_bh[0])

# Drop nan rows
data_bh = data_bh.mask(data_bh.eq('None')).dropna()

# Convert numbers to ints
data_bh['log(Lx)'] = pd.to_numeric(data_bh['#log(Lx)'])
data_bh['log(L_nu_OIR)'] = pd.to_numeric(data_bh['log(L_nu_OIR)'])
display(data_bh)
# Out:
#      #log(Lx)  log(L_nu_OIR)   Source    log(Lx)
# 0   35.431960      19.838653  XTE1118  35.431960
# 1   35.449931      19.778650  XTE1118  35.449931
# 2   35.471375      19.966659  XTE1118  35.471375
# 3   35.174038      19.538684  XTE1118  35.174038
# 4   35.431960      19.883565  XTE1118  35.431960
# ..        ...            ...      ...        ...
# 71  37.794537      21.763187  GX339-4  37.794537
# 72  36.484711      20.909701  GX339-4  36.484711
# 73  36.913656      21.189714  GX339-4  36.913656
# 74  36.484711      20.825672  GX339-4  36.484711
# 75  36.484711      20.884817  GX339-4  36.484711
#
# [76 rows x 4 columns]

# %%
tbl = pd.read_csv('preprocessed_data_avg.csv')
valid = ~(np.isnan(tbl['L_X']) | np.isnan(tbl['L_NIR']))
tbl = tbl[valid]
display(tbl.head())

states = pd.read_csv('FSRED Mags - total_source_list.csv')
nss = states[(states['NS/BH']=='NS') | (states['NS/BH']=='NS ') | (states['NS/BH']=='NS (UC)')]['Source'].to_list()
tbl = tbl[tbl['Source'].isin(nss)]
# Out:
#    Unnamed: 0           Source Filter  Obs_number Detected Name    Date obs  \
# 0           0  RX_J1735.3-3540      J        3081             S  2014-05-07
# 1           2  RX_J1735.3-3540      H        3063             S  2014-05-07
# 2           4  RX_J1735.3-3540     Ks        3045             S  2014-05-07
# 3           6           UW_Crb     Ks        1081             S  2018-06-19
# 4           7           UW_Crb      H        1086             S  2018-06-19
#
#                     RA                 DEC  Error_circle (arcsec)  \
# 0          17 35 23.75         -35 40 16.1                   0.56
# 1          17 35 23.75         -35 40 16.1                   0.56
# 2          17 35 23.75         -35 40 16.1                   0.56
# 3  16 05 45.8746697208  25 51 45.246497976                   0.10
# 4  16 05 45.8746697208  25 51 45.246497976                   0.10
#
#                  Position_source  ...  log_L_NIR_errup_nodist  \
# 0              Israel+2008, UVOT  ...                0.003808
# 1              Israel+2008, UVOT  ...                0.002848
# 2              Israel+2008, UVOT  ...                0.003019
# 3  Gaia Collaboration 2020, Gaia  ...                0.051416
# 4  Gaia Collaboration 2020, Gaia  ...                0.038230
#
#    log_L_NIR_errlow_nodist  log_L_NIR_errup_noflux  log_L_NIR_errlow_noflux  \
# 0                 0.003808                     NaN                      NaN
# 1                 0.002848                     NaN                      NaN
# 2                 0.003019                     NaN                      NaN
# 3                 0.051416                     NaN                      NaN
# 4                 0.038230                     NaN                      NaN
#
#    log_L_X_errup_nodist  log_L_X_errlow_nodist  log_L_X_errup_noflux  \
# 0              0.108574               0.108574                   NaN
# 1              0.108574               0.108574                   NaN
# 2              0.108574               0.108574                   NaN
# 3                   NaN                    NaN                   NaN
# 4                   NaN                    NaN                   NaN
#
#    log_L_X_errlow_noflux  log_L_NIR_upplim  log_L_X_upplim
# 0                    NaN               NaN             NaN
# 1                    NaN               NaN             NaN
# 2                    NaN               NaN             NaN
# 3                    NaN               NaN             NaN
# 4                    NaN               NaN             NaN
#
# [5 rows x 67 columns]

# %%
nir_Ks, nir_H, nir_J = [], [], []
x_Ks, x_H, x_J = [], [], []
tot_nir_NS= []
tot_X_NS = []
for index, row in tbl.iterrows():
    band = row['Filter']
    L_ergs = row['L_NIR']
    c = 2.9979e18 # A/s

    if band == 'Ks':
        W_eff = 3163.40 # A
        Hz = c/W_eff
        L_ergsHz = L_ergs / Hz
        
        nir_Ks.append(np.log10(L_ergsHz))
        x_Ks.append(row['log_L_X'])
        
    if band == 'H':
        W_eff = 2769.45 # A 
        Hz = c/W_eff
        L_ergsHz = L_ergs / Hz
        
        nir_H.append(np.log10(L_ergsHz))
        x_H.append(row['log_L_X'])    
        
    if band == 'J':
        W_eff = 2214.62 # A
        Hz = c/W_eff
        L_ergsHz = L_ergs / Hz
        
        nir_J.append(np.log10(L_ergsHz))
        x_J.append(row['log_L_X'])

    tot_nir_NS.append(np.log10(L_ergsHz))
    tot_X_NS.append(row['log_L_X'])

# %%
tbl2 = pd.read_csv('preprocessed_data_avg.csv')
valid = ~(np.isnan(tbl2['L_X']) | np.isnan(tbl2['L_NIR']))
tbl2 = tbl2[valid]

states = pd.read_csv('FSRED Mags - total_source_list.csv')
bhs = states[(states['NS/BH']=='BH') | (states['NS/BH']=='BH ')]['Source'].to_list()
tbl_BH = tbl2[tbl2['Source'].isin(bhs)]

nir_Ks_BH, nir_H_BH, nir_J_BH = [], [], []
x_Ks_BH, x_H_BH, x_J_BH = [], [], []
tot_nir_BH = []
tot_X_BH = []
for index, row in tbl_BH.iterrows():
    band = row['Filter']
    L_ergs = row['L_NIR']
    c = 2.9979e18 # A/s

    if band == 'Ks':
        W_eff = 3163.40 # A
        Hz = c/W_eff
        L_ergsHz = L_ergs / Hz
        
        nir_Ks_BH.append(np.log10(L_ergsHz))
        x_Ks_BH.append(row['log_L_X'])
        
    if band == 'H':
        W_eff = 2769.45 # A 
        Hz = c/W_eff
        L_ergsHz = L_ergs / Hz
        
        nir_H_BH.append(np.log10(L_ergsHz))
        x_H_BH.append(row['log_L_X'])    
        
    if band == 'J':
        W_eff = 2214.62 # A
        Hz = c/W_eff
        L_ergsHz = L_ergs / Hz
        
        nir_J_BH.append(np.log10(L_ergsHz))
        x_J_BH.append(row['log_L_X'])

    tot_nir_BH.append(np.log10(L_ergsHz))
    tot_X_BH.append(row['log_L_X'])

# %%
fig, ax = plt.subplots(1,3,figsize = (15, 5))

ax[0].scatter(x_Ks, nir_Ks)
ax[0].scatter(x_Ks_BH, nir_Ks_BH)
ax[0].scatter(data[data['Filter'] == 'K']['log(Lx)'], data[data['Filter'] == 'K']['log(L_nu_OIR)'])
# ax[0].scatter(data_bh[data_bh['Filter'] == 'K']['log(Lx)'], data_bh[data_bh['Filter'] == 'K']['log(L_nu_OIR)'])
ax[0].set_xlim(30, 39)
ax[0].set_ylim(16, 23)
ax[0].set_title('Ks band')
ax[0].set_ylabel(r'$\mathrm{log_{10}(L_{NIR}; erg/s/Hz)}$', fontsize=14)
ax[0].set_xlabel(r'$\mathrm{log_{10}(L_{X}; erg/s)}$', fontsize=14)

ax[1].scatter(x_H, nir_H)
ax[1].scatter(x_H_BH, nir_H_BH)
ax[1].scatter(data[data['Filter'] == 'H']['log(Lx)'], data[data['Filter'] == 'H']['log(L_nu_OIR)'])
# ax[1].scatter(data_bh[data_bh['Filter'] == 'H']['log(Lx)'], data_bh[data_bh['Filter'] == 'H']['log(L_nu_OIR)'])
ax[1].set_xlim(30, 39)
ax[1].set_ylim(16, 23)
ax[1].set_title('H band')
ax[1].set_xlabel(r'$\mathrm{log_{10}(L_{X}; erg/s)}$', fontsize=14)


ax[2].scatter(x_J, nir_J, label='new NS')
ax[2].scatter(x_J_BH, nir_J_BH, label='new BH')
ax[2].scatter(data[data['Filter'] == 'J']['log(Lx)'], data[data['Filter'] == 'J']['log(L_nu_OIR)'], label='Russell+2006 NS')
# ax[2].scatter(data_bh[data_bh['Filter'] == 'J']['log(Lx)'], data_bh[data_bh['Filter'] == 'J']['log(L_nu_OIR)'], label='Russell+2006 hard BH')
ax[2].set_xlim(30, 39)
ax[2].set_ylim(16, 23)
ax[2].set_title('J band')
ax[2].legend()
ax[2].set_xlabel(r'$\mathrm{log_{10}(L_{X}; erg/s)}$', fontsize=14)

plt.show()

# %%
plt.scatter(data['log(Lx)'], data['log(L_nu_OIR)'])

# %%
last_source = None
colors = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7", 'grey', 'C0', 'C1']
i=0
for index, row in data_bh.iterrows():
    s = row['Source']
#     print(s)
    # every source gets a new shape-color combination
    if s != last_source: 
        i +=1
    c = colors[i]
    plt.scatter(row['log(Lx)'], row['log(L_nu_OIR)'], c=c, label=s)
    last_source = s
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='upper center', bbox_to_anchor=(0.5, -0.1),
          fancybox=True, shadow=True, ncol=5)
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize = (10, 10))
plt.scatter(data_bh['log(Lx)'], data_bh['log(L_nu_OIR)'], label='Russell+2006 BH (hard)')
plt.scatter(data['log(Lx)'], data['log(L_nu_OIR)'], label='Russell+2006 NS')
plt.scatter(tot_X_BH, tot_nir_BH, label='new BH (quiescence)')
plt.scatter(tot_X_NS, tot_nir_NS, label='new NS')
plt.legend()
plt.ylabel(r'$\mathrm{log_{10}(L_{NIR}; erg/s/Hz)}$', fontsize=14)
plt.xlabel(r'$\mathrm{log_{10}(L_{X}; erg/s)}$', fontsize=14)
plt.show()

# %%
lm_bh_russell = LinMix(data_bh['log(Lx)'], data_bh['log(L_nu_OIR)'], K=2, seed=2)
lm_bh_russell.run_mcmc(silent=False)
lm_ns_russell = LinMix(data['log(Lx)'], data['log(L_nu_OIR)'], K=2, seed=2)
lm_ns_russell.run_mcmc(silent=False)
lm_bh = LinMix(tot_X_BH, tot_nir_BH, K=2, seed=2)
lm_bh.run_mcmc(silent=False)
lm_ns = LinMix(tot_X_NS, tot_nir_NS, K=2, seed=2)
lm_ns.run_mcmc(silent=False)
# Out:
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99101358 0.99081902 0.99267692 0.99611742 1.00179594 0.99579902]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99784204 0.99780702 0.99660382 0.99780545 0.99773937 0.99812792]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00338223 1.00337467 0.99880163 0.99797222 1.00556961 1.00034818]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00450748 1.00448794 1.00006169 0.99922928 1.00529891 1.00387597]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00295826 1.00306266 1.00112084 0.99922008 1.00517818 1.00458285]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00295771 1.00308958 1.00068144 0.99904994 1.00489202 1.00238469]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00188544 1.00200553 1.000474   0.99940771 1.00326028 1.00230317]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00272246 1.00283482 1.00050498 0.99979374 1.00352466 1.00391731]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00267145 1.00277442 1.00058767 0.99949839 1.00099047 1.0031368 ]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00152121 1.00160451 1.00010685 0.99985409 1.0023129  1.00214495]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0010853  1.00113933 0.99961257 1.00078555 1.00162078 1.00184404]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00133779 1.00140218 0.99980025 1.00111624 1.00101908 1.00185322]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0014084  1.00144954 0.9997502  1.00047417 1.00101942 1.0013386 ]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00160854 1.00163809 0.99963683 1.00032471 1.00085846 1.00146951]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00162359 1.00163592 0.99967508 1.00031467 1.00073455 1.00128952]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00221355 1.00221849 0.99976596 1.00053466 1.00024089 1.00172751]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00208772 1.00207778 0.99982408 1.00131077 1.00014119 1.00155917]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00126066 1.00125362 0.99990398 1.00082885 1.00019465 1.00115928]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0012501  1.00123163 1.00010798 1.00070928 0.99979377 1.00127893]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00158165 1.00156106 0.99998447 1.0009333  0.99992363 1.00145695]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00120037 1.00117997 0.99980968 1.00061662 0.99982493 1.00072239]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0009579  1.00093425 0.99974665 1.00041347 0.99988947 1.00045397]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00108061 1.00106502 1.0000071  1.00035093 0.99983274 1.00053983]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00092758 1.00091302 1.000034   1.00047867 0.9998469  1.00045094]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046325 1.0004512  1.00002915 1.0004987  0.99990299 1.00040376]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0005293  1.000516   0.9999903  1.00059216 0.99990079 1.00051756]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035789 1.00034616 1.00002894 1.00044474 0.9999401  1.00038613]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016524 1.00015638 0.99987325 1.00036488 0.99983106 1.00021307]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023655 1.00022937 0.9997978  1.00046249 0.99985125 1.00024074]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00018343 1.00017632 0.9997624  1.00056698 0.99983842 1.00022572]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00028748 1.00027971 0.99976623 1.00070879 0.99985373 1.00020891]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00036639 1.00036427 0.99978657 1.00058677 0.99986993 1.00023407]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00028029 1.00027703 0.99980971 1.00057424 0.99988787 1.00015341]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00034418 1.00033791 0.99986855 1.00055659 0.99986776 1.00023843]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046675 1.00046143 1.00001421 1.00051948 0.99991939 1.00035813]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00041115 1.00040444 1.00001004 1.00053863 0.99990559 1.00028177]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00034823 1.00034004 0.99999774 1.00042861 0.99985733 1.00006817]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00033399 1.00032581 0.99998734 1.00040506 0.99986029 1.00003102]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00041302 1.00040739 1.00005007 1.00041453 0.99982837 1.00007737]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039447 1.00039113 1.00005287 1.0006151  0.99982413 1.00007846]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00042926 1.00042096 1.00005328 1.00062509 0.99981852 1.0000877 ]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00030401 1.00029873 1.00011257 1.00064246 0.99982294 1.00011401]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00027841 1.00027236 1.00011026 1.00058572 0.99981149 1.00010559]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00027367 1.00026373 1.00011858 1.00058244 0.9998236  1.00006475]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013021 1.00012405 1.00013917 1.00059871 0.99981228 1.00002192]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00016072 1.0001531  1.00011547 1.00057845 0.99982921 0.99998905]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0002173  1.00020845 1.00008538 1.00054597 0.99984095 1.00000224]
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00023238 1.00022336 1.00005676 1.00053465 0.99984256 1.00001867]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00020265 1.00019139 1.00000556 1.00043577 0.99986023 0.99994091]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00015397 1.00014262 0.99997146 1.00051902 0.99985693 0.9999358 ]
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.01524375 1.01431752 0.99065384 1.01595329 0.99981855 0.99804115]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00378192 1.0034083  0.99810475 1.00995437 1.00195559 1.00410247]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00364782 1.00327122 0.99814374 1.01294022 1.00486029 1.01089861]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9994028  0.99921348 0.99951485 1.00834662 1.00354631 1.00483891]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99907902 0.9989472  0.99961688 1.00874066 1.00109497 1.00366038]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99925842 0.99916837 1.00028299 1.0067502  1.00080854 1.00331635]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99919864 0.99913162 0.9997954  1.00500381 1.00064191 1.00240851]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99916218 0.99914082 0.99952325 1.00415916 1.00055451 1.00191853]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99919724 0.99917575 0.99929418 1.0064642  1.00063925 1.00217959]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9995347  0.99954026 0.99968266 1.00775958 1.00080009 1.00262768]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980553 0.99982396 0.99980447 1.00696987 1.00100794 1.00351457]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991003 0.99993964 0.99970081 1.0068364  1.00108191 1.00365224]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99971245 0.99972775 0.9997342  1.00475924 1.0001312  1.00143227]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997127  0.999722   0.99971796 1.00295675 1.00009536 1.00063601]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980087 0.99980741 0.99979788 1.00211656 0.99966488 0.99981843]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981512 0.99982628 0.99977381 1.00146361 0.99979662 0.99969244]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99974698 0.99977    0.99976638 1.0016023  0.99971108 0.99955776]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988963 0.99991282 0.99983941 1.00113438 0.99964134 0.9996043 ]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99972918 0.99975788 0.99992988 1.00104105 0.99959988 0.99960903]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99966413 0.99969218 0.99988669 1.0010672  0.99960435 0.99972583]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99961193 0.99963288 0.99997785 1.00100987 0.99962001 0.99966342]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99972662 0.99975653 1.00007737 1.00103441 0.99961946 0.99980293]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99969068 0.99971828 1.00006666 1.00091945 0.99962954 0.99974605]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979153 0.99982714 1.00014784 1.00083937 0.99963992 0.99971321]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980829 0.99984573 0.99995603 1.00084402 0.99966984 0.99967702]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980011 0.99983152 1.00001031 1.00075535 0.99970785 0.9997775 ]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981674 0.9998497  1.00008886 1.0008896  0.99974776 0.99993407]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997303  0.99974971 1.00024388 1.00092285 0.99973207 0.99984645]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997186  0.99973505 1.00014744 1.00128775 0.99971655 0.99988985]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99970195 0.9997148  1.00008662 1.00127344 0.999809   0.99984991]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99971557 0.99972524 1.00012566 1.00070935 0.99992418 0.99982729]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99969912 0.99970595 1.00006334 1.00038519 0.99991326 0.99978209]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99971352 0.99972076 1.00006229 1.00028428 0.99988579 0.99973388]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997151  0.99971801 1.00003942 1.00024392 0.99995881 0.99982013]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997468  0.99975313 1.00001338 1.00037655 1.00014206 1.00008919]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975314 0.99975878 0.99997362 1.00045463 1.0002082  1.00041096]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99976379 0.99976682 0.99992854 1.00066576 1.00020691 1.00054961]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975271 0.99975444 0.99997349 1.00051416 0.99999473 1.0005265 ]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975598 0.99975771 0.99991168 1.00048358 0.99999594 1.00065737]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975343 0.99975518 0.99989122 1.00057086 0.99999597 1.00041867]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997585  0.99975976 0.99988471 1.00045139 0.99999725 1.00038622]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99976517 0.9997639  0.99990186 1.00032182 1.00000511 1.00045328]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99977255 0.99977076 0.9999205  1.00028925 1.00015594 1.00058832]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99977446 0.99977421 0.99996945 1.00029169 1.00015296 1.00092735]
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99978008 0.9997792  0.99998382 1.00019845 1.0001503  1.00124399]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99978513 0.99978713 0.99995855 1.00036074 1.00014696 1.00128351]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979119 0.99979196 0.99995661 1.00054251 1.00014293 1.00137718]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979357 0.99979436 0.99991384 1.00072087 0.99996184 1.00084789]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980559 0.99980794 0.99990432 1.00075989 0.99996267 1.00072756]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980817 0.999811   0.99990015 1.00076929 0.99996351 1.00066711]
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9929325  0.99346784 1.00670979 1.01814587 0.99989498 1.0118484 ]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00107209 1.00152931 0.99867023 1.00776922 1.00261385 1.00609009]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00111774 1.00136969 1.00031324 1.00285644 1.00295693 1.01248863]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00064144 1.00070395 0.99916125 1.00085291 1.00154703 0.99960999]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9988933  0.99890931 0.99873252 1.00094372 0.99977323 0.99885136]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99894193 0.99896421 1.00008575 1.0001594  0.99985045 0.99969033]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99921266 0.9992125  0.99973768 0.99990654 0.99982818 1.00028402]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986016 0.99982258 1.00014225 0.99918043 0.99979686 1.00010134]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99964647 0.99960941 1.00047371 0.99917838 0.99979802 1.00006323]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99938132 0.99936583 1.00045593 0.9991248  0.99982521 1.00091669]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99930927 0.99929651 1.00101788 0.99916772 0.99991099 1.00196392]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99935719 0.99933113 1.00105087 0.99928317 0.99992641 1.00197039]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99959259 0.99956639 1.00069228 0.99939003 0.99993382 1.00121766]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99970526 0.99969232 1.00029286 0.99936758 0.99993321 1.00199386]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000129   1.00011577 0.99993489 0.99938829 0.9999332  0.99999718]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00013952 1.00013492 0.99988806 0.9994352  0.99988145 0.99990409]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995145 0.99994906 1.00013244 0.99947848 0.99992894 1.00028815]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99997904 0.99998251 1.00012219 0.99965563 1.00038627 1.00017285]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010786 1.00011719 0.99976137 0.99971656 1.00038025 1.00038563]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00021531 1.00023065 0.99970158 0.9998982  1.0003822  1.00062963]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00004395 1.00005371 0.99966284 1.0001656  1.00037793 1.00089621]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995503 0.99996103 0.99970841 0.99999905 1.00035742 1.0009625 ]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00002781 1.00003581 0.99985189 1.00001379 1.00038277 1.00205936]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99993001 0.99993289 0.99987221 0.99992351 1.00037679 1.0021926 ]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992398 0.99992785 0.99994508 0.99973721 1.00036875 1.00223937]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998616 0.99998414 0.99983993 0.99976819 1.00035814 1.00265506]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999631  0.99996096 0.99996756 0.99977325 1.00034747 1.00250729]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006784 1.00006801 1.00002235 0.99982751 1.00032996 1.00248785]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003074 1.00003069 1.00002621 0.99998954 1.00024854 1.00211751]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00001376 1.00001381 1.00005042 0.99993345 1.0002089  1.00198963]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995966 0.9999595  1.00016322 0.99984485 1.00020353 1.00207286]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999875  0.99998627 1.00004984 0.99977668 1.00005043 1.00260654]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99999274 0.99999842 1.00030324 0.99978835 1.00004858 1.00224133]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986398 0.99986957 1.00018375 0.9998011  1.00004662 1.00262236]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986139 0.99986739 1.00014573 0.99984964 1.00005279 1.00255897]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988717 0.99989165 1.00011617 0.99989137 1.00005718 1.00284986]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999206  0.99992724 1.00005862 1.00000869 1.00005182 1.0024747 ]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991565 0.99992332 1.00001717 0.99994053 0.99991806 1.00241102]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992357 0.99993317 0.99998362 0.99996031 0.9999327  1.00276243]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991003 0.99991722 0.99999769 0.999976   0.99993696 1.00288018]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987863 0.9998837  1.00018032 0.99997215 0.99993785 1.00223668]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988669 0.99989257 1.00011931 1.00006131 0.99992438 1.00176167]
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989886 0.99990329 1.00011955 1.00004591 0.99992543 1.0013279 ]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990882 0.99991607 1.000093   0.99999413 0.99992512 1.00143223]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992728 0.99993171 1.00006135 0.99995627 0.99994687 1.0013286 ]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991237 0.9999147  1.00014205 0.99990144 0.99994429 1.00128566]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989564 0.99989471 1.00015427 1.00000297 0.99994543 1.00121802]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989793 0.99989932 1.00014761 1.00003637 0.99993466 1.00119602]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988505 0.99988654 1.00015424 0.99999269 0.9999252  1.00102379]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998923  0.99989311 1.00009725 0.99994225 0.99990489 1.00085782]
#
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99578108 0.99627468 0.99815749 1.01327682 1.00635046 1.00468274]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00254364 1.00247868 0.99821329 1.00624688 1.00029902 1.00712693]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00241432 1.0021869  0.99909437 1.00047899 0.99877926 1.00521879]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00187837 1.00164355 0.99948852 0.99938732 0.9985918  1.00369042]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00231145 1.00215584 0.99970616 0.99940357 0.99908792 1.00357618]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995483 0.99985145 0.9992292  0.99930115 1.00010674 1.00133756]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000715 0.99996102 0.99916907 0.9993799  1.00027061 1.0006476 ]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99931062 0.99931415 0.99902234 0.99907995 1.00022524 0.99964107]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99942174 0.99941297 0.99911144 0.99921213 0.99982093 0.99944946]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9992976  0.9992927  0.99949484 0.99942657 0.99974109 0.99939252]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99951493 0.99948092 0.99987474 0.99927738 1.00002637 0.99963833]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99973795 0.9996864  0.99970629 0.99929971 0.99989299 0.99969773]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99972704 0.99968662 0.9997985  0.99930822 1.00024267 0.99971964]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99969334 0.99965496 0.99958885 0.9995519  1.00054618 0.99987005]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99966411 0.99964326 0.99967799 0.99949288 1.00059669 0.99984857]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99963586 0.99962218 0.99984182 0.9994309  1.00037209 0.99975684]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99960569 0.99960687 0.99997257 0.99953713 1.00054356 0.99959384]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980413 0.99981153 1.00016378 0.99975334 1.0002953  0.99954794]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985143 0.99986737 0.99998519 0.99971388 1.0000824  0.999563  ]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99974444 0.99975281 0.99983989 0.9996492  1.00004063 0.99956676]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99973409 0.99974018 0.99986967 0.99964352 1.00018084 0.99966814]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99972453 0.99972893 0.99981672 0.9996906  1.00012059 0.99966092]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99978709 0.99977981 0.99993591 0.99973372 1.00015622 0.99970734]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9998032  0.99979455 1.00005712 0.99969004 1.00016204 0.99981652]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996049 0.99995896 1.00026094 0.99966119 1.00005439 0.99984275]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992422 0.99992071 1.0002132  0.999654   1.00004477 0.99980972]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988548 0.9998858  1.00012931 0.99967816 1.00004762 0.99976498]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99984793 0.99984867 1.00005293 0.99970489 0.9999367  0.99975469]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986803 0.99986602 1.00011636 0.99981347 0.9999486  0.99978603]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985565 0.99984877 1.0000963  0.99981931 0.99995927 0.99977184]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991844 0.99991015 1.00004408 0.99982767 0.99998257 0.99982061]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996142 0.9999511  1.00007868 0.9998727  1.00007942 0.99985554]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99998081 0.99996759 1.00012071 0.99983894 1.00016823 0.99985823]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99994822 0.99993375 1.00009503 0.99987962 1.00019191 0.99982187]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99991741 0.99990378 1.00012317 0.99991616 1.00010838 0.99978351]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990848 0.99989632 1.00009894 0.99994809 1.00021054 0.99978464]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990534 0.99989114 1.0000676  0.99991011 1.00029979 0.99978544]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9999117  0.99989829 1.00005202 0.99990632 1.00027706 0.99979675]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987234 0.99985838 0.99998547 0.99989049 1.00029379 0.99977255]
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981097 0.9998029  1.00001802 0.99986232 1.00028176 0.99978398]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9997758  0.99977214 1.00006012 0.99988276 1.00026354 0.99978481]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99978624 0.99978143 1.00008545 0.99987691 1.00030091 0.99978906]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99980456 0.99979959 1.00010461 0.99981947 1.0002792  0.99983098]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99979716 0.999794   1.00011413 0.9997878  1.00024934 0.99983684]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99981896 0.9998142  1.00009313 0.99981414 1.00025034 0.99982346]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99985101 0.99984628 1.00000032 0.99982105 1.00023991 0.99983731]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99986474 0.99986074 1.0000172  0.99980022 1.00015137 0.99984724]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987708 0.99987257 1.00007166 0.99979559 1.00009553 0.99984891]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989019 0.99988483 0.99998214 0.99980274 1.00007578 0.99982964]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990898 0.99990313 1.00002242 0.99981493 1.00007124 0.99983027]

# %%
# fig, ax = plt.subplots(1,1,figsize = (10, 10))
# plt.scatter(data_bh['log(Lx)'], data_bh['log(L_nu_OIR)'], label='Russell+2006 BH (hard)')
# plt.scatter(data['log(Lx)'], data['log(L_nu_OIR)'], label='Russell+2006 NS')
# plt.scatter(tot_X_BH, tot_nir_BH, label='new BH (quiescence)')
# plt.scatter(tot_X_NS, tot_nir_NS, label='new NS')
# plt.legend()
# plt.ylabel(r'$\mathrm{log_{10}(L_{NIR}; erg/s/Hz)}$', fontsize=14)
# plt.xlabel(r'$\mathrm{log_{10}(L_{X}; erg/s)}$', fontsize=14)
# plt.show()

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(121)
# ax.scatter(x_ns, y_ns, alpha=0.5)
# ax.errorbar(x_ns, y_ns, xerr=xsig_ns, yerr=ysig_ns, ls=' ', alpha=0.5)
# ax.scatter(x_bh, y_bh, alpha=0.5, color='C1')
# ax.errorbar(x_bh, y_bh, xerr=xsig_bh, yerr=ysig_bh, ls=' ', alpha=0.5, color='C1')
ax.scatter(data_bh['log(Lx)'], data_bh['log(L_nu_OIR)'], label='Russell+2006 BH (hard)')
ax.scatter(data['log(Lx)'], data['log(L_nu_OIR)'], label='Russell+2006 NS')
ax.scatter(tot_X_BH, tot_nir_BH, label='new BH (quiescence)')
ax.scatter(tot_X_NS, tot_nir_NS, label='new NS')
for i in range(0, len(lm_bh_russell.chain), 25):
    xs = np.arange(30,41)
    ys = lm_bh_russell.chain[i]['alpha'] + xs * lm_bh_russell.chain[i]['beta']
    ax.plot(xs, ys, color='C0', alpha=0.02)
for i in range(0, len(lm_ns_russell.chain), 25):
    xs = np.arange(30,41)
    ys = lm_ns_russell.chain[i]['alpha'] + xs * lm_ns_russell.chain[i]['beta']
    ax.plot(xs, ys, color='C1', alpha=0.02)
for i in range(0, len(lm_bh.chain), 25):
    xs = np.arange(30,41)
    ys = lm_bh.chain[i]['alpha'] + xs * lm_bh.chain[i]['beta']
    ax.plot(xs, ys, color='C2', alpha=0.02)
for i in range(0, len(lm_ns.chain), 25):
    xs = np.arange(30,41)
    ys = lm_ns.chain[i]['alpha'] + xs * lm_ns.chain[i]['beta']
    ax.plot(xs, ys, color='C3', alpha=0.02)
    
# ys = alpha + xs * beta
# ax.plot(xs, ys, color='k')
ax.set_xlabel(r'x')
ax.set_ylabel(r'y')
ax.set_xlim(30,40)
# ax.set_ylim(30,38)
# ax.plot([-6,6,6,-6,-6], [-3,-3,4,4,-3], color='k')
plt.legend()
plt.ylabel(r'$\mathrm{log_{10}(L_{NIR}; erg/s/Hz)}$', fontsize=14)
plt.xlabel(r'$\mathrm{log_{10}(L_{X}; erg/s)}$', fontsize=14)
fig.tight_layout()

# %%
print(np.mean(lm_bh_russell.chain['beta']), np.std(lm_bh_russell.chain['beta']))
print(np.mean(lm_ns_russell.chain['beta']), np.std(lm_ns_russell.chain['beta']))
print(np.mean(lm_bh.chain['beta']), np.std(lm_bh.chain['beta']))
print(np.mean(lm_ns.chain['beta']), np.std(lm_ns.chain['beta']))
# Out:
# 0.5566669943038324 0.04227749791065724
# 0.8050138173364008 0.07498752331901924
# 0.6544220176188945 0.07483303074799344
# 0.21825066411167107 0.046666479119060536

# %%
plt.scatter(lm_bh_russell.chain['beta'], lm_bh_russell.chain['alpha'], s=0.1, color='C0')
plt.scatter(lm_ns_russell.chain['beta'], lm_ns_russell.chain['alpha'], s=0.1, color='C1')
plt.scatter(lm_bh.chain['beta'], lm_bh.chain['alpha'], s=0.1, color='C2')
plt.scatter(lm_ns.chain['beta'], lm_ns.chain['alpha'], s=0.1, color='C3')
plt.xlabel('slope')
plt.ylabel('offset')
plt.show()

# %%
tot_x = np.concatenate((data_bh['log(Lx)'], data['log(Lx)'], tot_X_BH, tot_X_NS), axis=None)
tot_y = np.concatenate((data_bh['log(L_nu_OIR)'], data['log(L_nu_OIR)'], tot_nir_BH, tot_nir_NS), axis=None)
blobs = pd.DataFrame({'x': tot_x, 'y': tot_y})

# %%
colors = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7", 'grey']

# %%
import hdbscan

clusterer = hdbscan.HDBSCAN(min_cluster_size=2)
clusterer.fit(blobs)
blobs.loc[:,"label_hdb"] = clusterer.labels_


groups = blobs.groupby('label_hdb')

i=0
for name, group in groups:
    c=colors[i]
    i += 1
    plt.plot(group['x'], group['y'], marker='o', linestyle='', markersize=6, label=name, c=c)
plt.xlim(30, 39)
plt.ylim(31, 36)    
plt.xlabel(r'$\mathrm{log_{10}(L_{X}; erg/s)}$', fontsize=16)
plt.ylabel(r'$\mathrm{log_{10}(L_{NIR}; erg/s)}$', fontsize=16)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [44], in <cell line: 11>()
#      10 i=0
#      11 for name, group in groups:
# ---> 12     c=colors[i]
#      13     i += 1
#      14     plt.plot(group['x'], group['y'], marker='o', linestyle='', markersize=6, label=name, c=c)
#
# IndexError: list index out of range

# %%
L_ergs = 10**35
W_eff = 2214.62 # A
c = 2.9979e18 # A/s
Hz = c/W_eff
L_ergsHz = L_ergs / Hz
print(L_ergsHz)
# Out:
# 7.387237733079822e+19

# %%
l = 1e-6 #m 
l_A = l * 1e10 # A
print(l_A)
Hz2 = c/l_A
L_ergs = L_ergsHz * Hz2
print(L_ergs)
# Out:
# 10000.0
# 2.2146199999999997e+34

# %%
L_H = 10**20.3724412747791
W_eff_H = 2769.45 # A 
Hz = c/W_eff_H
L_H_tot = L_H * Hz

L_K = 10**20.1946223201326
W_eff_K = 3163.40 # A
Hz = c/W_eff_K
L_K_tot = L_K * Hz

print(L_H_tot, L_K_tot)
print(np.log10(L_H_tot), np.log10(L_K_tot))
print(np.log10(L_H_tot+L_K_tot))
# Out:
# 2.551907264213739e+35 1.483492489591031e+35
# 35.40686488816353 35.1712853519758
# 35.60588656316519
