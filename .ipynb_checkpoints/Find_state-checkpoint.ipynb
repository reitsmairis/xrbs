# %%
from astropy.io import ascii
import matplotlib.pyplot as plt

# %%
source = "4U_1702-429" 
filepath = "E:/Scriptie/Spectra/Hardness_state/" + source
bat_flname = filepath + "/" + "4U1702-429.lc.txt"
maxi_flname = filepath + "/" +  "J1645-456_g_lc_maxi.dat"
data_BAT = ascii.read(bat_flname)  
data_maxi = ascii.read(maxi_flname)

# %%
print(data_maxi)
# Out:
#   col1    col2     col3     col4     col5     col6     col7      col8     col9
# ------- -------- -------- -------- -------- -------- -------- --------- --------
# 55053.5 1.335898 0.190678 0.757088 0.144155  0.62922 0.104112 -0.003751 0.063531
# 55054.5 1.846635 0.150166 0.746198 0.103444 0.916054 0.084279  0.044371 0.047345
# 55056.5  1.66528 0.040197 0.642603 0.027744 0.738097 0.022408  0.168635  0.01441
# 55057.5 1.366547 0.021003 0.498385 0.013899 0.613556 0.011557  0.146104 0.008298
# 55058.5 1.378415 0.019974 0.533114 0.013616 0.612717 0.010923  0.132017 0.007574
# 55059.5 1.369284 0.019622  0.48531 0.012897  0.61387 0.010773   0.15064 0.007667
# 55060.5 1.283891  0.01905 0.468179 0.012641 0.574061 0.010413  0.138216 0.007501
# 55061.5 1.658959 0.021568 0.607818 0.014489 0.762514 0.012047  0.147608 0.007713
# 55062.5 1.812275 0.024252 0.700697 0.016917 0.824697 0.013592  0.148741 0.007993
# 55063.5 1.425939 0.021184  0.56011 0.014745 0.630633 0.011625  0.133464 0.007635
#     ...      ...      ...      ...      ...      ...      ...       ...      ...
# 60006.5 1.615345 0.029545 0.656899 0.020709 0.724556 0.016289  0.123196  0.01018
# 60007.5 1.703199 0.031663 0.736137 0.022802 0.750525 0.017316  0.127848 0.011027
# 60008.5 1.571022 0.029748 0.699141 0.021617  0.71524 0.016635  0.074081  0.00933
# 60009.5 1.764506 0.034462 0.730597 0.024339 0.787268 0.019227  0.141224 0.011761
# 60010.5 1.431834 0.031053 0.580902  0.02154  0.63021 0.017125   0.13091 0.011469
# 60011.5 1.725078 0.035545 0.743504 0.025472 0.775708 0.019932  0.111729 0.011722
# 60012.5 1.500247 0.032903 0.608244 0.022871 0.667315  0.01833  0.129702 0.011817
# 60013.5 1.434506 0.035528 0.572588 0.024535 0.620986 0.019489  0.155275 0.013748
# 60014.5 1.446265 0.050017 0.585919 0.034826 0.626842 0.026899  0.147748 0.019744
# 60015.5 1.354424 0.030872 0.501468 0.020432  0.59927 0.016944  0.147245   0.0121
# 60016.5 1.846449 0.050873 0.698442 0.034225 0.847785  0.02835  0.156857 0.018419
# Length = 4023 rows

# %%
JD = 58288 # TODO omreken stukje code?

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))
ax1.plot(data_BAT[ 'col1'], data_BAT['col2'], 'o', ms=1, label='BAT')
ax2.plot(data_maxi[ 'col1'], data_maxi['col2'], 'o', ms=1, color='C1', label='MAXI')
ax1.set_title('BAT data')
ax2.set_title('MAXI data')
ax1.set_ylabel('counts/cm2/sec (15-50 keV)')
ax1.set_xlabel('MJD')
ax2.set_ylabel('counts/cm2/sec (2-20 keV)')
ax2.set_xlabel('MJD')
plt.show()

# %%
# TODO normalisatie automatiseren? 
x_up = JD + 150
x_low = JD - 150
y_up = 0.04
y_low = -0.02
norm = 100

# m1 = data_XRT['col2'].mean()
# m2 = data_maxi['col2'].mean()
# print(data_XRT['col2'].mean())
# print(data_maxi['col2'].mean())
# print(m2/m1/2)

plt.plot(data_BAT[ 'col1'], data_BAT['col2'], 'o', ms=1, label='BAT')
plt.plot(data_maxi[ 'col1'], data_maxi['col2']/norm, 'o', ms=1, color='C1', label='MAXI')
plt.ylim(y_low, y_up)
plt.xlim(x_low, x_up)
plt.vlines(JD, y_low, y_up, 'Red', label='obs')
plt.legend(loc='upper left')
plt.ylabel('counts (arbitrary)')
plt.xlabel('MJD')
plt.show()
