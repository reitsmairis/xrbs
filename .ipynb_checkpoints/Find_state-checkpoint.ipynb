# %% [markdown]
# # Lightcurve inspection for determining X-ray state
#
# This notebook is used to open Swift/BAT and MAXI ligthcurve data to estimate if the object is in the hard of soft state during our observations when that is unknown. Swift/BAT observes mostly hard photons, while MAXI observes mostly soft photons. Thus, comparing both lightcurves indicates the X-ray binary state.
#
# Author: Iris Reitsma

# %%
"""
Importing all libraries needed.
"""


from astropy.io import ascii
from astropy.time import Time

import matplotlib.pyplot as plt

# %%
""" 
Defining parameters and importing the Swift/BAT and MAXI ligthcurve data.

PARAMETERS to be set by the user:
- source: name of the XRB. Needs to match the correspondng directory name;
- date: date of the NIR observation
- bat_flname: insert filename of the BAT lightcurve data
- maxi_flname: insert filename of the MAXI ligthcurve data
"""

source = "XSS_J12270-4859" 
date = '2014-05-8' # YYYY MM DD
filepath = "E:/Scriptie/Spectra/Hardness_state/" + source
bat_flname = filepath + "/" + "XSSJ12270-4859.lc.txt"
maxi_flname = filepath + "/" +  "J1227-488_g_lc_maxi.dat"

t = Time(date, scale='utc')
data_BAT = ascii.read(bat_flname)  
data_maxi = ascii.read(maxi_flname)  
figname_state = filepath + '/' + source + "_statefig.png"

print(data_maxi)
# Out:
#   col1     col2     col3      col4   ...    col6     col7      col8     col9
# ------- --------- -------- --------- ... --------- -------- --------- --------
# 55051.5 -0.042264 0.056995  0.017681 ... -0.012978 0.023646 -0.045075 0.037139
# 55053.5 -0.024967 0.029735 -0.021577 ...  0.000626 0.013341 -0.009652 0.020447
# 55054.5 -0.011385 0.032597 -0.030959 ...   0.01149 0.014669  -2.4e-05 0.022044
# 55055.5   0.01172  0.01693 -0.003468 ...  0.000662  0.00752  0.010501 0.011358
# 55056.5  0.005135 0.021155  0.004998 ... -0.001873 0.009368  0.006233 0.013398
# 55057.5  0.006835  0.00949  0.000744 ...  0.008791   0.0041 -0.004692 0.006339
# 55058.5  0.002235 0.009365  -0.00022 ...  0.000812 0.004119   0.00088 0.006227
# 55059.5  0.002223 0.009328  0.002115 ...  0.005231 0.004096 -0.005606 0.006203
# 55060.5  0.003764 0.009283  0.005103 ... -0.002127 0.004055  0.003331 0.006145
# 55061.5  0.001252 0.009574  0.006252 ...  0.004737 0.004175 -0.009705 0.006359
#     ...       ...      ...       ... ...       ...      ...       ...      ...
# 60003.5  0.586398 0.056487  0.162511 ...  0.143751 0.027402   0.23775 0.032229
# 60004.5 -0.150499 0.050082 -0.039759 ... -0.026532 0.022101 -0.081249   0.0326
# 60005.5  0.185078 0.051645  0.046981 ...  0.068962  0.02325  0.049726 0.032556
# 60018.5 -0.004562 0.017955  0.004037 ...  0.006365 0.007892 -0.013459 0.011422
# 60019.5  0.002497 0.018115  -0.00762 ... -0.002003 0.007795  0.009247 0.011762
# 60020.5  0.017285 0.016779  0.001249 ... -0.000732 0.007488  0.015124 0.010968
# 60021.5  0.018448 0.033263 -0.002674 ...  0.017113 0.014749  0.000211 0.022349
# 60025.5  0.014393 0.018963   0.00719 ... -0.004905 0.008056  0.016236 0.013054
# 60026.5 -0.006583 0.016251 -0.009272 ... -0.002035 0.007037  0.003581 0.011166
# 60027.5  0.002459 0.033035  -0.00216 ...  0.018732 0.014052 -0.019616 0.022071
# 60028.5  0.010707 0.032171  0.006508 ...  0.000313 0.013804  0.010275  0.02153
# Length = 4125 rows

# %%
""" 
Plot both lightcurves separately
"""

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))
ax1.plot(data_BAT[ 'col1'], data_BAT['col2'], 'o', ms=1, label='BAT')
ax2.plot(data_maxi[ 'col1'], data_maxi['col2'], 'o', ms=1, color='C1', label='MAXI')
ax1.set_title('BAT data')
ax2.set_title('MAXI data')
ax1.set_ylabel('counts/cm2/sec (15-50 keV)')
ax1.set_xlabel('MJD')
ax2.set_ylabel('counts/cm2/sec (2-20 keV)')
ax2.set_xlabel('MJD')
ax1.set_xlim(x_low, x_up)
ax2.set_xlim(x_low, x_up)
ax2.set_ylim(-0.1, 0.2)
ax1.set_ylim(-0.01, 0.01)
plt.show()

# %%
""" 
Plot both lightcurves together, also with the time of NIR observation.
Because the lightcurves are on different scales, we need to rescale them 
for a good comparison.
"""

# Set the parameters for plotting (boundaries, normalization)
print(t.mjd)
x_up = t.mjd + 200
x_low = t.mjd - 200
y_up = 0.02
y_low = -0.02
norm = 7

# Plot the lightcurves and observation day
plt.plot(data_BAT[ 'col1'], data_BAT['col2']-0.01, 'o', ms=1, label='BAT')
plt.plot(data_maxi[ 'col1'], data_maxi['col2']/norm, 'o', ms=1, color='C1', label='MAXI')
plt.ylim(y_low, y_up)
plt.xlim(x_low, x_up)
plt.vlines(t.mjd, y_low, y_up, 'Red', label='obs')
plt.legend(loc='upper left')
plt.ylabel('counts (arbitrary)')
plt.xlabel('MJD')
plt.savefig(figname_state)
plt.show()
# Out:
# 56785.0
