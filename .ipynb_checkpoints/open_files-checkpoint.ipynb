# %%
"""
Importing all libraries needed.
"""

from astropy.io import fits
import numpy as np
from scipy.odr import *
from astropy.coordinates import SkyCoord
from astroquery.vo_conesearch import ConeSearch
from scipy.ndimage import interpolation
from astropy import units as u
from astropy import constants as c
import astropy.coordinates as coord
from astropy import wcs
import aplpy
import matplotlib.pyplot as plt
from astropy.coordinates import ICRS,FK4
import math
import re

import pandas as pd

# %%
coords = "15 38 13.68 -55 42 13.1" 
source = "AX_J1538.3-5541"
obs = "1026"
file_name = "2018-06-18_Ks_AX_J1538.3-5541_1026_c1-4_58287_99250.mos.fits.cat"
FSRED_dir = "E:/Scriptie/"

flname = FSRED_dir + "FSRED/u018918_data/" + source + "/" + file_name # SExtractor catalog from the Taurus computer


XRB_coo = SkyCoord(coords, unit=(u.hourangle,u.deg))

# %%
# coords = "17 38 58.300 -44 27 00.00 "
# source = "4U_1735-44"
# obs = "1148" # H
# file_name = "2018-06-19_H_4U_1735-44_1148_c1-4_58288_17457.mos.fits.cat"

# FSRED_dir = "E:/Scriptie/"

# flname = FSRED_dir + "FSRED/u018918_data/" + source + "/" + file_name # SExtractor catalog from the Taurus computer


# XRB_coo = SkyCoord(coords, unit=(u.hourangle,u.deg))

# %%
# coords = "17 38 58.300 -44 27 00.00 "
# source = "4U_1735-44"
# obs = "1153" # J 
# file_name = "2018-06-19_J_4U_1735-44_1153_c1-4_58288_18215.mos.fits.cat"

# FSRED_dir = "E:/Scriptie/"

# flname = FSRED_dir + "FSRED/u018918_data/" + source + "/" + file_name # SExtractor catalog from the Taurus computer


# XRB_coo = SkyCoord(coords, unit=(u.hourangle,u.deg))

# %% [markdown]
# # Try to open mos.fits file
# I can indeed see there are 4 chips, with the source in the middle of one of them

# %%
gc = aplpy.FITSFigure(flname[:-4]) # this is the mos.fits file
gc.show_colorscale(cmap='gist_heat_r',stretch='arcsinh')
gc.show_markers(XRB_coo.ra.deg, XRB_coo.dec.deg, 
                edgecolor='red', facecolor='none',
                marker='o', s=80, alpha=1)
gc.recenter(XRB_coo.ra.deg, XRB_coo.dec.deg, 
            radius=20/3600.)# degrees
gc.set_theme('publication')
# Out:
# INFO: Auto-setting vmin to -3.375e+01 [aplpy.core]
# INFO: Auto-setting vmax to  7.350e+03 [aplpy.core]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [3], in <cell line: 6>()
#       2 gc.show_colorscale(cmap='gist_heat_r',stretch='arcsinh')
#       3 gc.show_markers(XRB_coo.ra.deg, XRB_coo.dec.deg,
#       4                 edgecolor='red', facecolor='none',
#       5                 marker='o', s=80, alpha=1)
# ----> 6 gc.recenter(XRB_coo.ra.deg, XRB_coo.dec.deg,
#       7             radius=20/3600.)# degrees
#       8 gc.set_theme('publication')
#
# File ~\anaconda3\lib\site-packages\aplpy\decorators.py:26, in auto_refresh.<locals>.wrapper(*args, **kwargs)
#      23 mydata.nesting = getattr(mydata, 'nesting', 0) + 1
#      25 try:
# ---> 26     return f(*args, **kwargs)
#      27 finally:
#      28     mydata.nesting -= 1
#
# File ~\anaconda3\lib\site-packages\aplpy\core.py:517, in FITSFigure.recenter(self, x, y, radius, width, height)
#     510     raise Exception("Need to specify either radius= or width= and height= arguments")
#     512 if (xpix + dx_pix < -0.5 or
#     513     xpix - dx_pix > self._wcs.nx - 0.5 or
#     514     ypix + dy_pix < -0.5 or
#     515         ypix - dy_pix > self._wcs.ny):
# --> 517     raise Exception("Zoom region falls outside the image")
#     519 self.ax.set_xlim(xpix - dx_pix, xpix + dx_pix)
#     520 self.ax.set_ylim(ypix - dy_pix, ypix + dy_pix)
#
# Exception: Zoom region falls outside the image

# %%
# hdu=headerList[1]
# print('shape :',hdu.shape) #shape is 1024*1024

# %% [markdown]
# # Try to open mos.fits.cat file
# Its hard to try something with pandas because of multidimensional columns

# %%
data = fits.getdata(flname,ext=2)
print(data.columns)
print(type(data))
# Out:
# WARNING: File may have been truncated: actual file length (122945536) is smaller than the expected size (186096960) [astropy.io.fits.file]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 data = fits.getdata(flname,ext=2)
#       2 print(data.columns)
#       3 print(type(data))
#
# File ~\anaconda3\lib\site-packages\astropy\io\fits\convenience.py:206, in getdata(filename, header, lower, upper, view, *args, **kwargs)
#     204 try:
#     205     hdu = hdulist[extidx]
# --> 206     data = hdu.data
#     207     if data is None:
#     208         if ext_given:
#
# File ~\anaconda3\lib\site-packages\astropy\utils\decorators.py:777, in lazyproperty.__get__(self, obj, owner)
#     775         val = obj_dict.get(self._key, _NotFound)
#     776         if val is _NotFound:
# --> 777             val = self.fget(obj)
#     778             obj_dict[self._key] = val
#     779 return val
#
# File ~\anaconda3\lib\site-packages\astropy\io\fits\hdu\table.py:400, in _TableBaseHDU.data(self)
#     398 @lazyproperty
#     399 def data(self):
# --> 400     data = self._get_tbdata()
#     401     data._coldefs = self.columns
#     402     data._character_as_bytes = self._character_as_bytes
#
# File ~\anaconda3\lib\site-packages\astropy\io\fits\hdu\table.py:170, in _TableLikeHDU._get_tbdata(self)
#     167     data = raw_data[:tbsize].view(dtype=columns.dtype,
#     168                                   type=np.rec.recarray)
#     169 else:
# --> 170     raw_data = self._get_raw_data(self._nrows, columns.dtype,
#     171                                   self._data_offset)
#     172     if raw_data is None:
#     173         # This can happen when a brand new table HDU is being created
#     174         # and no data has been assigned to the columns, which case just
#     175         # return an empty array
#     176         raw_data = np.array([], dtype=columns.dtype)
#
# File ~\anaconda3\lib\site-packages\astropy\io\fits\hdu\base.py:522, in _BaseHDU._get_raw_data(self, shape, code, offset)
#     519     return np.ndarray(shape, dtype=code, buffer=self._buffer,
#     520                       offset=offset)
#     521 elif self._file:
# --> 522     return self._file.readarray(offset=offset, dtype=code, shape=shape)
#     523 else:
#     524     return None
#
# File ~\anaconda3\lib\site-packages\astropy\io\fits\file.py:324, in _File.readarray(self, size, offset, dtype, shape)
#     321             else:
#     322                 raise
# --> 324     return np.ndarray(shape=shape, dtype=dtype, offset=offset,
#     325                       buffer=self._mmap)
#     326 else:
#     327     count = reduce(operator.mul, shape)
#
# TypeError: buffer is too small for requested array

# %%
hdulist = fits.open(flname)
hdulist.info()
# Out:
# Filename: E:/Scriptie/FSRED/u018918_data/4U_1735-44/2018-06-19_H_4U_1735-44_1148_c1-4_58288_17457.mos.fits.cat
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  LDAC_IMHEAD    1 BinTableHDU     12   1R x 1C   [12320A]
#   2  LDAC_OBJECTS    1 BinTableHDU     62   72968R x 14C   [1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1I, 625E, 1E]
