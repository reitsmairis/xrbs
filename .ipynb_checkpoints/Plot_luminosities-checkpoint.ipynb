# %% [markdown]
# # Luminosity plots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load in data
tbl = pd.read_csv('FSRED Mags - Final_python.csv')
display(tbl.head())

# TODO combine bands where needed
# Out:
#             Source Filter  Obs_number Detected Name    Date obs           RA  \
# 0  RX_J1735.3-3540      J        3081             S  2014-05-07  17 35 23.75
# 1  RX_J1735.3-3540      J        3090             S  2014-05-07  17 35 23.75
# 2  RX_J1735.3-3540      H        3063             S  2014-05-07  17 35 23.75
# 3  RX_J1735.3-3540      H        3072             S  2014-05-07  17 35 23.75
# 4  RX_J1735.3-3540     Ks        3045             S  2014-05-07  17 35 23.75
#
#            DEC  Error_circle (arcsec)    Position_source            nH  ...  \
# 0  -35 40 16.1                   0.56  Israel+2008, UVOT  5.760000e+21  ...
# 1  -35 40 16.1                   0.56  Israel+2008, UVOT  5.760000e+21  ...
# 2  -35 40 16.1                   0.56  Israel+2008, UVOT  5.760000e+21  ...
# 3  -35 40 16.1                   0.56  Israel+2008, UVOT  5.760000e+21  ...
# 4  -35 40 16.1                   0.56  Israel+2008, UVOT  5.760000e+21  ...
#
#    D_errup  D_errlow  Distance_source  Lum  Lum_err  Xray_Flux (erg/s/cm2)  \
# 0      NaN       NaN    Degenaar+2010  NaN      NaN           2.000000e-11
# 1      NaN       NaN    Degenaar+2010  NaN      NaN           2.000000e-11
# 2      NaN       NaN    Degenaar+2010  NaN      NaN           2.000000e-11
# 3      NaN       NaN    Degenaar+2010  NaN      NaN           2.000000e-11
# 4      NaN       NaN    Degenaar+2010  NaN      NaN           2.000000e-11
#
#      Xray_errup   Xray_errlow   Xray_Flux_source  \
# 0  5.000000e-12  5.000000e-12  Thesis Bilal 2018
# 1  5.000000e-12  5.000000e-12  Thesis Bilal 2018
# 2  5.000000e-12  5.000000e-12  Thesis Bilal 2018
# 3  5.000000e-12  5.000000e-12  Thesis Bilal 2018
# 4  5.000000e-12  5.000000e-12  Thesis Bilal 2018
#
#                                             Comments
# 0                                                NaN
# 1                                                NaN
# 2  Initially very large magnitude offset but seem...
# 3  Initially large magnitude offset but seems oka...
# 4  Initially large magnitude offset but seems oka...
#
# [5 rows x 33 columns]

# %%
# TODO determine luminosities based on flux and distance
def luminosity(flux, d):
    d_cm = 3.08567758128e21 * float(d) 
    L = 4 * np.pi * d_cm**2 * flux
    
    return L

def luminosity_error(flux, flux_error, d, d_error, L):
    # TODO
#     d_cm = 3.08567758128e21 * float(d) 
#     d_err_cm = 3.08567758128e21 * float(d_error) 
#     print( np.pi * np.sqrt((flux_error/flux)**2 + 2*(d_error/float(d))**2))
    L_err = np.sqrt((flux_error/flux)**2 + 2*(d_error/float(d))**2) * L # TODO dubbelcheck

    return L_err

tbl['L_NIR'] = tbl.apply(lambda x: luminosity(x['Flux (erg/s/cm2)'], x['Distance (kpc)']), axis=1)
tbl['L_X'] = tbl.apply(lambda x: luminosity(x['Xray_Flux (erg/s/cm2)'], x['Distance (kpc)']), axis=1)
tbl['L_NIR_errup'] = tbl.apply(lambda x: luminosity_error(x['Flux (erg/s/cm2)'], x['Flux_err'], x['Distance (kpc)'], x['D_errup'], x['L_NIR']), axis=1)
tbl['L_NIR_errlow'] = tbl.apply(lambda x: luminosity_error(x['Flux (erg/s/cm2)'], x['Flux_err'], x['Distance (kpc)'], x['D_errlow'], x['L_NIR']), axis=1)
tbl['L_X_errup'] = tbl.apply(lambda x: luminosity_error(x['Xray_Flux (erg/s/cm2)'], x['Xray_errup'], x['Distance (kpc)'], x['D_errup'], x['L_X']), axis=1)
tbl['L_X_errlow'] = tbl.apply(lambda x: luminosity_error(x['Xray_Flux (erg/s/cm2)'], x['Xray_errlow'], x['Distance (kpc)'], x['D_errlow'], x['L_X']), axis=1)

display(tbl.head())
# TODO how to handle upper limits in magnitude, distance and a combination of these? 
# TODO determine luminosity errors based on flux and distance errors
# TODO add luminosity + errors to paper tabel
# TODO uitzonderingen toevoegen
# Out:
#             Source Filter  Obs_number Detected Name    Date obs           RA  \
# 0  RX_J1735.3-3540      J        3081             S  2014-05-07  17 35 23.75
# 1  RX_J1735.3-3540      J        3090             S  2014-05-07  17 35 23.75
# 2  RX_J1735.3-3540      H        3063             S  2014-05-07  17 35 23.75
# 3  RX_J1735.3-3540      H        3072             S  2014-05-07  17 35 23.75
# 4  RX_J1735.3-3540     Ks        3045             S  2014-05-07  17 35 23.75
#
#            DEC  Error_circle (arcsec)    Position_source            nH  ...  \
# 0  -35 40 16.1                   0.56  Israel+2008, UVOT  5.760000e+21  ...
# 1  -35 40 16.1                   0.56  Israel+2008, UVOT  5.760000e+21  ...
# 2  -35 40 16.1                   0.56  Israel+2008, UVOT  5.760000e+21  ...
# 3  -35 40 16.1                   0.56  Israel+2008, UVOT  5.760000e+21  ...
# 4  -35 40 16.1                   0.56  Israel+2008, UVOT  5.760000e+21  ...
#
#      Xray_errup   Xray_errlow   Xray_Flux_source  \
# 0  5.000000e-12  5.000000e-12  Thesis Bilal 2018
# 1  5.000000e-12  5.000000e-12  Thesis Bilal 2018
# 2  5.000000e-12  5.000000e-12  Thesis Bilal 2018
# 3  5.000000e-12  5.000000e-12  Thesis Bilal 2018
# 4  5.000000e-12  5.000000e-12  Thesis Bilal 2018
#
#                                             Comments         L_NIR  \
# 0                                                NaN  3.196317e+34
# 1                                                NaN  3.055938e+34
# 2  Initially very large magnitude offset but seem...  4.589307e+34
# 3  Initially large magnitude offset but seems oka...  5.334394e+34
# 4  Initially large magnitude offset but seems oka...  4.168170e+34
#
#             L_X  L_NIR_errup  L_NIR_errlow  L_X_errup  L_X_errlow
# 0  2.159674e+35          NaN           NaN        NaN         NaN
# 1  2.159674e+35          NaN           NaN        NaN         NaN
# 2  2.159674e+35          NaN           NaN        NaN         NaN
# 3  2.159674e+35          NaN           NaN        NaN         NaN
# 4  2.159674e+35          NaN           NaN        NaN         NaN
#
# [5 rows x 39 columns]

# %%
states = pd.read_csv('FSRED Mags - total_source_list.csv')
quiescent_sources = states[states['Hard/soft state ']=='quiescence']['Source'].to_list()

tbl = tbl[tbl['Filter']=='Ks'] # TODO


fig, ax = plt.subplots(figsize = (9, 9))
xrange= np.logspace(29, 41, num=10)
y = 10**10.8 * xrange**(0.63)
ax.plot(xrange, y, c='g', label='Russell NS fit (slope 0.63)')
y_bh = 10**13.1 * xrange**0.61
ax.plot(xrange, y_bh, c='r', label='Russell BH fit (slope 0.61)')

ax.scatter(tbl['L_X'], tbl['L_NIR'], label='new')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('L_X (erg/s)')
ax.set_ylabel('L_NIR (erg/s)')
ax.set_xlim(10e30, 10e40)
ax.set_ylim(10e29, 10e39)
plt.legend()
plt.show()

fig, ax = plt.subplots(figsize = (9, 6))

for n, r in tbl.iterrows():
    s = r['Source']
    if s in quiescent_sources: 
        c = 'Red'
    else:
        c = 'Blue'
#     plt.scatter(ratio_list[n], source_list[n], color=c, zorder=10)
    ax.scatter(tbl['L_X'][n], tbl['L_NIR'][n], color=c)  
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('L_X (erg/s)')
ax.set_ylabel('L_NIR (erg/s)')
# ax.set_xlim(10e30, 10e40)
# ax.set_ylim(10e29, 10e39)
plt.show()
# Out:
# ['AX_J1538.3-5541', 'EXO_0748-676', 'EXO_0748-676', 'GX_339-4', 'GX_339-4', 'IGR_J17091-3624', 'IGR_J17494-3030', 'IGR_J17494-3030', 'MAXI_J0556-332', 'MAXI_J1305-704', 'MAXI_J1421-613', 'MXB_1659-28', 'MXB_1659-28', 'RXS_J180408.9-342058', 'RXS_J180408.9-342058', 'Swift_J1357.2-0933', 'Swift_J1357.2-0933', 'Swift_J1910.2-0546', 'Swift_J1910.2-0546', 'Swift_J1922.7-1716', 'Swift_J1922.7-1716', 'XTE_J1637-498', 'XTE_J1719-291']

# %%
fig, ax = plt.subplots(figsize = (9, 9))
xrange= np.logspace(29, 41, num=10)
y = 10**10.8 * xrange**(0.63)
ax.plot(xrange, y, c='g', label='Russell NS fit (slope 0.63)')
y_bh = 10**13.1 * xrange**0.61
ax.plot(xrange, y_bh, c='r', label='Russell BH fit (slope 0.61)')

# TODO upper limits toevoegen
ax.errorbar(tbl['L_X'], tbl['L_NIR'], yerr=[tbl['L_NIR_errlow'], tbl['L_NIR_errup']], xerr=[tbl['L_X_errlow'], tbl['L_X_errup']], label='new data', fmt='x', ms=5)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('L_X (erg/s)')
ax.set_ylabel('L_NIR (erg/s)')
ax.set_xlim(10e29, 10e39)
ax.set_ylim(10e28, 10e38)

# for i, row in tbl.iterrows():
#     ax.annotate(row['Source'], (tbl['L_X'][i], tbl['L_NIR'][i]))

plt.legend()
plt.show()

# TODO Add nice labels for sources

# %%
# TODO fit powerlaw to data?

# %%
# TODO compare powerlaw with models
