# %% [markdown]
# # Luminosity plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# TODO Load in data
tbl = pd.read_csv('test_table.csv')
display(tbl.head())
tbl = tbl[tbl['Source'].isin(['EXO_0748-676', 'RXS_J170854.4-321857', 'MAXI_J0556-332'])] #==['EXO_0748-676']) | (tbl['Source']=='RXS_J170854.4-321857')]
# TODO combine bands where needed
# Out:
#             Source Filter  Obs_number Detected Name    Date obs  \
# 0  RX_J1735.3-3540      J        3090             S  2014-05-07
# 1  RX_J1735.3-3540      H        3072             S  2014-05-07
# 2  RX_J1735.3-3540     Ks        3054             S  2014-05-07
# 3     EXO_0748-676      J        2836             S  2014-05-08
# 4     EXO_0748-676      H        2827             S  2014-05-08
#
#                RA            DEC  Error_circle (arcsec)    Position_source  \
# 0     17 35 23.75    -35 40 16.1                   0.56  Israel+2008, UVOT
# 1     17 35 23.75    -35 40 16.1                   0.56  Israel+2008, UVOT
# 2     17 35 23.75    -35 40 16.1                   0.60  Israel+2008, UVOT
# 3  07 48 33.70944  -67 45 07.722                   0.20    Monet+2003, PMM
# 4  07 48 33.70944  -67 45 07.722                   0.20    Monet+2003, PMM
#
#              nH  ...      Flux_err  Distance (kpc)  Distance_error  \
# ...

# %%
# TODO determine luminosities based on flux and distance
def luminosity(flux, d):
    d_cm = 3.08567758128e21 * float(d) 
    L = 4 * np.pi * d_cm**2 * flux
    
    return L

def luminosity_error(flux, flux_error, d, d_error, L):
    # TODO
#     d_cm = 3.08567758128e21 * float(d) 
#     d_err_cm = 3.08567758128e21 * float(d_error) 
    print( np.pi * np.sqrt((flux_error/flux)**2 + 2*(d_error/float(d))**2))
    L_err = np.sqrt((flux_error/flux)**2 + 2*(d_error/float(d))**2) * L # TODO dubbelcheck

    return L_err

tbl['L_NIR'] = tbl.apply(lambda x: luminosity(x['Flux (erg/s/cm2)'], x['Distance (kpc)']), axis=1)
tbl['L_X'] = tbl.apply(lambda x: luminosity(x['Xray_Flux (erg/s/cm2)'], x['Distance (kpc)']), axis=1)
tbl['L_NIR_err'] = tbl.apply(lambda x: luminosity_error(x['Flux (erg/s/cm2)'], x['Flux_err'], x['Distance (kpc)'], x['Distance_error'], x['L_NIR']), axis=1)
tbl['L_X_err'] = tbl.apply(lambda x: luminosity_error(x['Xray_Flux (erg/s/cm2)'], x['Xray_Flux_err'], x['Distance (kpc)'], x['Distance_error'], x['L_X']), axis=1)

display(tbl.head())
# TODO how to handle upper limits in magnitude, distance and a combination of these? 
# TODO determine luminosity errors based on flux and distance errors
# TODO add luminosity + errors to paper tabel
# Out:
# 0.6053140569622744
# 0.6128869995727919
# 0.7099758374471067
# 0.7936596601208389
# 0.7136668623391415
# 0.7097355835179513
# 1.4601658352011233
# 1.4654620185476326
# 1.0863899837814823
# 1.0863899837814823
# 1.0863899837814823
# 0.9284311414311593
# 0.9284311414311593
# 0.9284311414311593
# 2.5466476544983925
# 2.5466476544983925
#                   Source Filter  Obs_number Detected Name    Date obs  \
# 3           EXO_0748-676      J        2836             S  2014-05-08
# 4           EXO_0748-676      H        2827             S  2014-05-08
# 5           EXO_0748-676     Ks        2818             S  2014-05-08
# 9   RXS_J170854.4-321857     Ks         649             S  2013-06-18
# 10  RXS_J170854.4-321857      H         659             S  2013-06-18
#
#                 RA            DEC  Error_circle (arcsec)     Position_source  \
# 3   07 48 33.70944  -67 45 07.722                    0.2     Monet+2003, PMM
# ...

# %%
# TODO Create scatter plot of luminosities 
from matplotlib.colors import ListedColormap

tbl['grp'] = tbl.groupby('Source').ngroup()
fig, ax = plt.subplots(figsize = (9, 6))
print(tbl['grp'].values)
colors = ListedColormap(['r','b','g'])
ax.scatter(tbl['L_X'], tbl['L_NIR'], c=tbl['grp'].values, cmap=colors)
# ax.errorbar(tbl['L_X'], tbl['L_NIR'], xerr=tbl['L_X_err'], yerr=tbl['L_NIR_err'], fmt="o", color="r")
colors=['r', 'b', 'g']
for x, y, ex, ey, color in zip(tbl['L_X'], tbl['L_NIR'], tbl['L_X_err'], tbl['L_NIR_err'], colors):
#     plt.plot(x, y, 'o', color=color)
    ax.errorbar(x, y, ex, ey, color=color, fmt='o')

# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('L_X (erg/s)')
ax.set_ylabel('L_NIR (erg/s)')
fig.show()

# TODO Add nice labels for sources
# Out:
# [0 0 0 2 2 2 1 1]
# oi
# oi
# oi
# C:\Users\Iris Reitsma\AppData\Local\Temp\ipykernel_1516\2103231780.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# TODO Create scatter plot of luminosities 
from matplotlib.colors import ListedColormap

tbl['grp'] = tbl.groupby('Source').ngroup()
fig, ax = plt.subplots(figsize = (9, 6))
colors = ListedColormap(['r','b','g'])
ax.errorbar(tbl['L_X'], tbl['L_NIR'], xerr=tbl['L_X_err'], yerr=tbl['L_NIR_err'], fmt="o", color="k", zorder=0.1, alpha=0.4)
ax.scatter(tbl['L_X'], tbl['L_NIR'], c=tbl['grp'].values, cmap=colors)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('L_X (erg/s)')
ax.set_ylabel('L_NIR (erg/s)')
plt.show()
# TODO Add nice labels for sources

# %%
# TODO fit powerlaw to data

# %%
# TODO compare powerlaw with models
